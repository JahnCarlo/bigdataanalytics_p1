# %%
filepath = "countTweetsPerUserResult"
contents = []

with open(filepath) as fp:
    entry = []
    line = fp.readline().split()
    for i in line:
        entry.append(i)
    contents.append(entry)
    while line:
        entry = []
        line = fp.readline().split()
        for i in line:
            entry.append(i)
        contents.append(entry)
        
modified = []

#print(len(contents))

for entry in contents:
    try:
        if(entry[1] > '5' and len(entry) == 2):
            modified.append(entry)
    except:
        print ("EOF Reached")
        

sortedList = sorted(modified , key=lambda x: int(x[1]))
goodSorted = list(reversed(sortedList))

#Clean and format into one, get first 1000 to analyze
cleanSorted = []
for element in goodSorted[:551]:
    try:
        cleanSorted.append(element[0] + ", " + element[1])
    except:
        print("Index out of bounds")


#Print to screen for use
for element in cleanSorted:
    print(element)
# Out:
# EOF Reached
# feryooit, 6666
# zikavirusmap, 684
# TimClarkeArt, 590
# cbc_diff, 93
# Siubhan_H, 90
# parentapproved1, 84
# doritmi, 84
# kidoctr, 83
# djt10, 76
# DonnaYoungDC, 75
# GetMyGist, 74
# Rosewind2007, 73
# Vaccinizer, 71
# Plasticdoe, 71
# LesleyKempson, 68
# HelenBranswell, 66
# tmj_WAK_GOVERN, 65
# chrisvcsefalvay, 63
# EmmaGPaley, 63
# TBM_Janitorial, 62
# BeckyJohnson222, 60
# AllenCWest, 59
# SDCountyHHSA, 57
# MackayIM, 55
# eHealthyDaily, 54
# capsio_eu, 54
# CDCFlu, 52
# wk2hd, 9
# trtworld, 9
# thrivingwithoil, 9
# stevescrutton, 9
# skyintist, 9
# mccarthy_ph, 9
# master_usmle_rv, 9
# krfabian, 9
# hpscireland, 9
# heatherslg, 9
# h2only, 9
# gorskon, 9
# brown_denism, 9
# TuSNHD, 9
# TommyKrasker, 9
# StopVaxxedLies, 9
# ShinjinGuardian, 9
# SarloMarilyn, 9
# SarahMarieGraye, 9
# SNHDflu, 9
# PrimaryCare4um, 9
# POVengage, 9
# OndineBio, 9
# OnblD, 9
# OhioAMF, 9
# Northlinesdaily, 9
# NVPeople, 9
# NVICLoeDown, 9
# NOfNews_Ireland, 9
# NHSLeicester, 9
# MsTrixter, 9
# MBHolistic, 9
# LouiseDewast, 9
# LadyAnon5, 9
# LREwoke, 9
# LLUHealth, 9
# KikiAdine, 9
# JulieLeask, 9
# JamieNWilkinson, 9
# Honest33321, 9
# HenningTveit, 9
# HealthyPinellas, 9
# HHLGroupLimited, 9
# GaryEther, 9
# Francissy125, 9
# EurekaMag, 9
# Emma__Peel, 9
# EbolaNewsViews, 9
# ECG_MK, 9
# DrRonaldHoffman, 9
# DrFrancesRyan, 9
# DHSWI, 9
# ConsumerReports, 9
# ChrysMuirhead, 9
# ChronicTami, 9
# CallieSimon, 9
# CDCGlobal, 9
# CAPublicHealth, 9
# BarryHingley, 9
# Barb_Randolph1, 9
# AuglaizeHealth, 9
# Askxpert, 9
# Alex__Tortolero, 9
# 9_11_IsAnInside, 9
# 1a, 9
# yceek, 8
# xtnetworks, 8
# womaneasy, 8
# wildcardacehigh, 8
# weezyme, 8
# vnuek, 8
# vScienceBites, 8
# trendingpress1, 8
# toppediatrician, 8
# thetimewall, 8
# srccg, 8
# squirrelalice, 8
# soulwareGDev, 8
# sickweather, 8
# seatsitters, 8
# rub_me_wrong_, 8
# rsbellmedia, 8
# rcraverWSJ, 8
# queer_i_am, 8
# qkode, 8
# outbreaksci, 8
# ohhiimdoug, 8
# nuiotwo, 8
# npnikk, 8
# niccibelli, 8
# naveenthacker, 8
# mshizwick, 8
# modhealthtalk, 8
# maverick4pa, 8
# maidrightnopho, 8
# lj_tan, 8
# letstalkcentral, 8
# keithgrimes, 8
# jim_herd, 8
# jeanetteimpia, 8
# hiphopscypher, 8
# gertienicphilib, 8
# fishflytogether, 8
# erikwilson1975, 8
# erikmoldwarrior, 8
# emtannie, 8
# ejptacek, 8
# diseases_an, 8
# diaronex, 8
# ddtwitjokes, 8
# danaparish, 8
# cindygallop, 8
# chrishendel, 8
# calderdaleccg, 8
# cakiebutbut, 8
# bullatrix1967, 8
# alykhansatchu, 8
# _FLEX4U, 8
# YNews__, 8
# World_Health_Be, 8
# WellnessInitiat, 8
# WellVanderbilt, 8
# VdlchJ, 8
# UniusRei, 8
# Ukachiigboko, 8
# UKHomeopathyReg, 8
# TruthtellerDX, 8
# TroyCoby, 8
# TheCouponPlanet, 8
# TastyCa60374227, 8
# TEWV, 8
# TEN4Texas, 8
# ShotofPrev, 8
# RWT_NHS, 8
# RRInternational, 8
# ProfJRSmith, 8
# PHE_uk, 8
# PATHtweets, 8
# NotOfIt7k, 8
# NewsDingo, 8
# MrJackDawg, 8
# MadiLutshele, 8
# Luxotek, 8
# LowCarbMag, 8
# LaurenWeberHP, 8
# LSHTM, 8
# KP_KernCounty, 8
# KPHawaii, 8
# Jarecot, 8
# IMC_UK, 8
# GreenTipGuy, 8
# GovCanHealth, 8
# GaviSeth, 8
# GSU_Research, 8
# GPI_AEPap, 8
# FreeBeeCee, 8
# FluBeeGame, 8
# EurekaStockade3, 8
# EdDarrell, 8
# DrCorriel, 8
# DoncasterLPC, 8
# CrawliesWithCri, 8
# Channel__News, 8
# ChanceAustin, 8
# Cat_Kapow, 8
# CanadanewsMedia, 8
# CWPT_Heref_Imms, 8
# CIIimpact, 8
# BuzzFeedNews, 8
# Ash_Tree_House, 8
# AbrahamThePharm, 8
# AUC31, 8
# 9NewsSyd, 8
# 1jewish_prince, 8
# 1Lifedirect, 8
# 1Anson1, 8
# 12345sw6789, 8
# yoururgentcare, 7
# yorurin, 7
# wrg53, 7
# wowcheckitout, 7
# waynerohde, 7
# tv9gujarati, 7
# tkbetts, 7
# tatterededge, 7
# sidselmarie_, 7
# ruthheasman, 7
# rogerscott, 7
# richdavisphd, 7
# realphildabney1, 7
# realiwasframed, 7
# rapshack_co_uk, 7
# public_affairs, 7
# nicolacois, 7
# myShockerHealth, 7
# mistycarole, 7
# mhh_heron, 7
# medical_tweets, 7
# maxxxvip, 7
# martavision, 7
# lyndac68, 7
# lucasgonzalez, 7
# leenysman63, 7
# laurakrabappel, 7
# hydrangone, 7
# hidalgohealth, 7
# hannyka6, 7
# followlasg, 7
# flujabs, 7
# elliothealthsys, 7
# drsherbdr3, 7
# deepvard, 7
# clintonkowach, 7
# chngin_the_wrld, 7
# charlesweijer, 7
# blicqer, 7
# bjhealthtips, 7
# barav, 7
# backtoschoolart, 7
# babyname_maven, 7
# azemarketing, 7
# abtassociates, 7
# _TheRealBecky1, 7
# Zoono_USA, 7
# ZikaPLAN, 7
# YourFeetCome1st, 7
# WriterJordyn, 7
# WitherellCT, 7
# WHOUganda, 7
# VinaigretteGirl, 7
# Vaccinate4Life, 7
# UnioByHarness, 7
# UberHealth4life, 7
# UNCpublichealth, 7
# UGAhealthcenter, 7
# TriviaMiami, 7
# TheObGProject, 7
# Tami_Bry, 7
# TAMUhealth, 7
# SummeryJen, 7
# SnackBoxDiet, 7
# SimonBradley22, 7
# Shivani23530657, 7
# SeattleMamaDoc, 7
# Scribberlings, 7
# SciSeekFeed, 7
# SamiAlsubaihi, 7
# SamDono10307721, 7
# S3npaicat, 7
# RealRedElephant, 7
# R2Pindex, 7
# PublicHealthW, 7
# PrimalSurge, 7
# PlumRemson, 7
# Photobiologica, 7
# PharmacistReb, 7
# PergamIC, 7
# PattyCole123, 7
# PaleoMessenger, 7
# PDFviewerForWp, 7
# NyQuilDayQuil, 7
# NimaDayani, 7
# NexusModel9, 7
# NetworkofnewsUK, 7
# NeofletperMaifl, 7
# NatureCutsTags, 7
# NHSMKCCG, 7
# NHPINDIA, 7
# NEJM, 7
# NCIRS, 7
# MyDoctorFriend, 7
# MuseumofCityNY, 7
# MoescatoB, 7
# MissionaryJapan, 7
# MethuselahsB, 7
# Med_Shadow, 7
# MagDMongoose, 7
# MSherylGraham2, 7
# MODPizzaUK, 7
# MHGURU, 7
# MDMagazine, 7
# Lil_Glizzee_, 7
# Levendaki17, 7
# LaurieEThomas, 7
# LauraC_9691, 7
# LancashireCare, 7
# LagosTownHall, 7
# LaLaRueFrench75, 7
# LGSentinel, 7
# KansasAAP, 7
# KISSMediaCo, 7
# KEWLBINX, 7
# JulieDziobon, 7
# JoyOfCats, 7
# InfectDisNews, 7
# ImmunizeNV, 7
# ImmunizeCa, 7
# IHME_UW, 7
# Hearing4Kids, 7
# HappilyH, 7
# GrumFromNorwich, 7
# GhostKarin, 7
# GboruM, 7
# EverydayHealth, 7
# Ethnography911, 7
# DrTedros, 7
# DrRafiqRaji, 7
# DrPanMD, 7
# DrJoeHaraszti, 7
# DrFine_bot, 7
# DancingTheMind, 7
# DanRWilsonPhD1, 7
# DailyTimes_9, 7
# DPT_Flufighters, 7
# Community_Peds, 7
# CollectableMr, 7
# ColinBBaker, 7
# CleggAndrea, 7
# ClearwaveU, 7
# ChelwestFT, 7
# Charliekuss, 7
# CSISHealth, 7
# BobRobez22, 7
# ArkansasOnline, 7
# AnahitaAredvi, 7
# Alexandria_SZ, 7
# AlanasFound, 7
# AkshithaAnanda1, 7
# ASMicrobiology, 7
# APIC, 7
# AFutterer, 7
# 9NewsQueensland, 7
# 912CroozeFM, 7
# 7NewsSydney, 7
# 7NewsBrisbane, 7
# 7NewsAdelaide, 7
# zippy94400851, 6
# yupfinglas, 6
# xileenie, 6
# wildwalkerwoman, 6
# wgby, 6
# wcti12, 6
# vikesmn24, 6
# vickiecouturier, 6
# vegannutrition1, 6
# vaccines4life, 6
# twooatsodasgary, 6
# traunte, 6
# toweroftruth, 6
# torstar_diff, 6
# tenaciousV56, 6
# sunny3marie, 6
# storiesflowcom, 6
# spikesandspokes, 6
# southbanklondon, 6
# soapdoesit, 6
# science_lan, 6
# schnuppideluxe, 6
# sbabij, 6
# rocza, 6
# right558, 6
# redbreastedbird, 6
# rbarishansky, 6
# randolphhealth, 6
# r_luba, 6
# puhinnalle_, 6
# publichealth4u, 6
# ptrdo, 6
# proballmetrics, 6
# pippaliciousj, 6
# pfectbabies, 6
# petermbenglish, 6
# pchd, 6
# passport_health, 6
# paras_sal, 6
# old_osc, 6
# nickmyer, 6
# nhs_sct, 6
# newsoneplace, 6
# newsnet__, 6
# neil_bodie, 6
# nachopepsiman, 6
# mylifestylecru1, 6
# myamigocouk, 6
# michael_w_busch, 6
# meowcarriemeow, 6
# marlene_mmm, 6
# mallikarjun456, 6
# lovechi60577687, 6
# loucheryl, 6
# loseyourgut, 6
# localpestcntrol, 6
# lilyO_darkwa, 6
# letswinpc, 6
# leehuiseng, 6
# kevinault, 6
# kemba722, 6
# katemshepherd, 6
# kateheydonorg, 6
# jonoquick, 6
# jknewsservice1, 6
# jeremyrhammond, 6
# jenefcforever, 6
# itijonline, 6
# iquantified, 6
# imheckifiknow, 6
# honigsbaum, 6
# hfxpublib, 6
# heathnews_news, 6
# hawkins_carole, 6
# handmadekathy, 6
# hahabirdpumpkin, 6
# guanochick, 6
# greeeneyedwhwom, 6
# genphys, 6
# forrestmaready, 6
# fludetector, 6
# fiski70, 6
# emilycolleens, 6
# emahase95, 6
# edrybicki, 6
# echoserviceinfo, 6
# eTweeetz, 6
# drsarahmac, 6
# dougmmilford, 6
# dj_ewi, 6
# disabilisaur, 6
# dailyhealthmate, 6
# connie_glbert, 6
# cockydahomomc, 6
# clickplaymovie, 6
# cccrehab, 6
# carolygarrison, 6
# cantab_biker, 6
# campamministry, 6
# camelcamelcamel, 6
# cacoethes_carpe, 6
# bsgbuzz, 6
# betabetic, 6
# besthealthyou, 6
# athieno_m, 6
# asherares, 6
# anoticingsenpai, 6
# anilkohli54, 6
# angelovalidiya, 6
# anantcshah, 6
# aliceclearman, 6
# ahmed_serougi, 6
# agent_mcgrath, 6
# YouScienceLIVE, 6
# WomenWriters, 6
# WithoutHisEyes, 6
# WilliamHnutsack, 6
# WellWheels, 6
# WV_DHHR, 6
# Voices4Vaccines, 6
# VirtualOutcome1, 6
# VMDToday, 6
# ThutoMsJood, 6
# The_News_DIVA, 6
# The_EARA, 6
# TheNotDoc, 6
# TakeThatSkeptic, 6
# TRjinkitty, 6
# TEDMED, 6
# SuzieQT11, 6
# SaludHEALTHinfo, 6
# RosanneRobinso1, 6
# RonaldKlain, 6
# RobRHC, 6
# ResearchCapREDe, 6
# Qandew, 6
# ProductJT, 6
# PPHCanada, 6
# PIH, 6
# OregonVacTruth, 6
# NewsChannelNYC, 6
# NYAMNYC, 6
# NOMO_Repellent, 6
# NHSKernow, 6
# NELincsCCG, 6
# NCISymptomMgmt, 6
# NCDCgov, 6
# NASciencesTeam, 6
# Mooseplainer, 6
# Miryam1968, 6
# Mikeggibbs, 6
# MikeHydro, 6
# MergersBio, 6
# MedStarVNA, 6
# MedResJourno, 6
# McGinleyAllison, 6
# MaryJo__Perry, 6
# MarianneEhrn, 6
# MacUmbridge, 6
# LouiseTeboul, 6
# LocalPestCont, 6
# LindsayPH, 6
# Lid055, 6
# LiamRSharp, 6
# LauraRe63376304, 6
# LancsHospHandWB, 6
# LTHTEmergencyPr, 6
# LLUMedCenter, 6
# KrisNBC, 6
# KonaNatureTours, 6
# KTVZ, 6
# KPRiverside, 6
# KPGeorgia, 6
# KDHE, 6
# KATVNews, 6
# JonathanLCFT, 6
# Joao77Cunha, 6
# JaylynneParsons, 6
# JasonTibbelsMD, 6
# JaneSmith659, 6
# JamieNugget, 6
# JAMAPediatrics, 6
# IrongirlNadia, 6
# InsideVaccines, 6
# ImmunizeBC, 6
# IleyLorraine, 6
# IVaccinateMI, 6
# ISARIC1, 6
